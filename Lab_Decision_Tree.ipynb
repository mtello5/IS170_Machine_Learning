# %% [markdown]
# <a href="https://colab.research.google.com/github/mtello5/IS170_Machine_Learning/blob/Decision-Trees-%26-Random-Forests/Lab_Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Matthew Tello/ Andres Perez

# %% [markdown]
# Pima Indians Lab

# %%
# Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
# load dataset
df = pd.read_csv("pima_indians_diabetes_data.csv") 
df.head()

# %%
#split dataset in features and target variable
x_data=df[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']]
y_data=df['Outcome']

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Model Accuracy
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# %% [markdown]
# Our own data begins here.

# %%
# Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-49c60023-d59c-4161-93e0-b2b6e8b5719f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-49c60023-d59c-4161-93e0-b2b6e8b5719f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# load dataset
data_frame = pd.read_csv("Brain Tumor.csv") 
data_frame.head()
# Out:
#     Image  Class      Mean     Variance  Standard Deviation   Entropy  \
# 0  Image1      0  6.535339   619.587845           24.891522  0.109059
# 1  Image2      0  8.749969   805.957634           28.389393  0.266538
# 2  Image3      1  7.341095  1143.808219           33.820234  0.001467
# 3  Image4      1  5.958145   959.711985           30.979219  0.001477
# 4  Image5      0  7.315231   729.540579           27.010009  0.146761
#
#    Skewness   Kurtosis    Contrast    Energy       ASM  Homogeneity  \
# 0  4.276477  18.900575   98.613971  0.293314  0.086033     0.530941
# 1  3.718116  14.464618   63.858816  0.475051  0.225674     0.651352
# 2  5.061750  26.479563   81.867206  0.031917  0.001019     0.268275
# 3  5.677977  33.428845  151.229741  0.032024  0.001026     0.243851
# 4  4.283221  19.079108  174.988756  0.343849  0.118232     0.501140
#
#    Dissimilarity  Correlation     Coarseness
# 0       4.473346     0.981939  7.458341e-155
# ...

# %%
#split dataset in features and target variable
x_data=data_frame[['Entropy','Skewness','Kurtosis','Contrast','Energy','ASM','Homogeneity','Dissimilarity','Correlation','Coarseness']]
y_data=data_frame['Class']

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Model Accuracy
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9849424269264836

# %% [markdown]
# Given the data we were able to get a 98% almost 99% accuracy on the Brain Tumor CSV file. Below you will see the visualization of the Decision tree.

# %% [markdown]
# # **Visualizing Decision Trees**

# %%
# !pip install graphviz
# !pip install pydotplus
# !pip install six
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from sklearn.tree import export_graphviz
from six import StringIO  
from IPython.display import Image  
import pydotplus


dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('Brain Tumor.png')
Image(graph.create_png())
